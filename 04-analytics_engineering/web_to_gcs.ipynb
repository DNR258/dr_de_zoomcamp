# %%
import io
import os
import requests
import pandas as pd
from google.cloud import storage

"""
Pre-reqs: 
1. `pip install pandas pyarrow google-cloud-storage`
2. Set GOOGLE_APPLICATION_CREDENTIALS to your project/service-account key
3. Set GCP_GCS_BUCKET as your bucket or change default value of BUCKET
"""

# services = ['fhv','green','yellow']
init_url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/'
# switch out the bucketname
BUCKET = "ny-taxi-datalake-88"
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='/home/drios/data-engineering-zoomcamp/dr_de_zoomcamp/04-analytics_engineering/my-creds.json'

fhv_dtypes = {
 'dispatching_base_num': str,
 'PUlocationID': pd.Int64Dtype(),
 'DOlocationID ': pd.Int64Dtype(),
 'SR_Flag': pd.Int64Dtype(),
 'Affiliated_base_number': str,
}

fhv_parse_dates = ['pickup_datetime', 'dropOff_datetime']

def upload_to_gcs(bucket, object_name, local_file):
    """
    Ref: https://cloud.google.com/storage/docs/uploading-objects#storage-upload-object-python
    """
    # # WORKAROUND to prevent timeout for files > 6 MB on 800 kbps upload speed.
    # # (Ref: https://github.com/googleapis/python-storage/issues/74)
    storage.blob._MAX_MULTIPART_SIZE = 3 * 1024 * 1024  # 5 MB
    storage.blob._DEFAULT_CHUNKSIZE = 3 * 1024 * 1024  # 5 MB

    client = storage.Client()
    bucket = client.bucket(bucket)
    blob = bucket.blob(object_name)
    blob.upload_from_filename(local_file)


def web_to_gcs(year, service):
    for i in range(12):
        
        # sets the month part of the file_name string
        month = '0'+str(i+1)
        month = month[-2:]

        # csv file_name
        file_name = f"{service}_tripdata_{year}-{month}.csv.gz"

        # download it using requests via a pandas df
        request_url = f"{init_url}{service}/{file_name}"
        r = requests.get(request_url)
        open(file_name, 'wb').write(r.content)
        print(f"Local: {file_name}")

        # read it back into a parquet file
        df = pd.read_csv(file_name, compression='gzip', dtype=fhv_dtypes, parse_dates=fhv_parse_dates)
        df.fillna(0, inplace=True)
        df['Affiliated_base_number'] = df['Affiliated_base_number'].astype(str)
        df['DOlocationID'] = df['DOlocationID'].astype(int)
        df['dispatching_base_num'] = df['dispatching_base_num'].astype(str)
        file_name = file_name.replace('.csv.gz', '.parquet')
        df.to_parquet(file_name, engine='pyarrow')
        print(f"Parquet: {file_name}")

        # upload it to gcs 
        upload_to_gcs(BUCKET, f"{service}/{file_name}", file_name)
        print(f"GCS: {service}/{file_name}")


# web_to_gcs('2019', 'green')
# web_to_gcs('2020', 'green')
# web_to_gcs('2019', 'yellow')
# web_to_gcs('2020', 'yellow')
web_to_gcs('2019', 'fhv')
# Out:
# Local: fhv_tripdata_2019-01.csv.gz
# Parquet: fhv_tripdata_2019-01.parquet
# GCS: fhv/fhv_tripdata_2019-01.parquet
# Local: fhv_tripdata_2019-02.csv.gz
# Parquet: fhv_tripdata_2019-02.parquet
# GCS: fhv/fhv_tripdata_2019-02.parquet
# Local: fhv_tripdata_2019-03.csv.gz
# Parquet: fhv_tripdata_2019-03.parquet
# GCS: fhv/fhv_tripdata_2019-03.parquet
# Local: fhv_tripdata_2019-04.csv.gz
# Parquet: fhv_tripdata_2019-04.parquet
# GCS: fhv/fhv_tripdata_2019-04.parquet
# Local: fhv_tripdata_2019-05.csv.gz
# Parquet: fhv_tripdata_2019-05.parquet
# GCS: fhv/fhv_tripdata_2019-05.parquet
# Local: fhv_tripdata_2019-06.csv.gz
# Parquet: fhv_tripdata_2019-06.parquet
# GCS: fhv/fhv_tripdata_2019-06.parquet
# Local: fhv_tripdata_2019-07.csv.gz
# Parquet: fhv_tripdata_2019-07.parquet
# GCS: fhv/fhv_tripdata_2019-07.parquet
# Local: fhv_tripdata_2019-08.csv.gz
# Parquet: fhv_tripdata_2019-08.parquet
# GCS: fhv/fhv_tripdata_2019-08.parquet
# Local: fhv_tripdata_2019-09.csv.gz
# Parquet: fhv_tripdata_2019-09.parquet
# GCS: fhv/fhv_tripdata_2019-09.parquet
# Local: fhv_tripdata_2019-10.csv.gz
# Parquet: fhv_tripdata_2019-10.parquet
# GCS: fhv/fhv_tripdata_2019-10.parquet
# Local: fhv_tripdata_2019-11.csv.gz
# Parquet: fhv_tripdata_2019-11.parquet
# GCS: fhv/fhv_tripdata_2019-11.parquet
# Local: fhv_tripdata_2019-12.csv.gz
# Parquet: fhv_tripdata_2019-12.parquet
# GCS: fhv/fhv_tripdata_2019-12.parquet

# %%
pip install pandas pyarrow google-cloud-storage
# Out:
# Requirement already satisfied: pandas in /home/drios/anaconda3/lib/python3.9/site-packages (1.4.2)
# Collecting pyarrow
#   Downloading pyarrow-15.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (38.3 MB)
#      |████████████████████████████████| 38.3 MB 28 kB/s  eta 0:00:01     |████████████████▋               | 19.9 MB 450 kB/s eta 0:00:41
# Requirement already satisfied: google-cloud-storage in /home/drios/anaconda3/lib/python3.9/site-packages (1.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/drios/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/drios/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/drios/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-cloud-storage) (1.33.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.0.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-cloud-storage) (1.3.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: setuptools>=40.3.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage) (61.2.0)
# Requirement already satisfied: six>=1.9.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage) (4.2.2)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.21.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (1.25.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (1.53.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (2.27.1)
# Requirement already satisfied: protobuf>=3.12.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (3.19.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage) (1.1.2)
# Requirement already satisfied: cffi>=1.0.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage) (1.15.0)
# Requirement already satisfied: pycparser in /home/drios/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/drios/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/drios/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/drios/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/drios/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/drios/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage) (1.26.9)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-15.0.0
# Note: you may need to restart the kernel to use updated packages.
